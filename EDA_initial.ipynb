# %%
# imports

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import re
import psycopg2
from sqlalchemy import create_engine, text

# %matplotlib inline
# %load_ext sql
# %config SqlMagic.displaylimit = 30
# %config SqlMagic.autolimit = 30
# Out:
# The sql extension is already loaded. To reload it, use:
#   %reload_ext sql

# %%
# Connecting to the database

import json
import urllib.parse
with open('credentials/credentials.json') as f:
    login = json.load(f)
    username = login['user']
    password = urllib.parse.quote(login['password'])
    host = login['host']
    port = login['port']

# %%
conn = create_engine(f'postgresql://{username}:{password}@{host}:{port}/football_transfermarkt')

# %%
data_appearances = pd.read_csv("data/appearances.csv")
data_club_games = pd.read_csv("data/club_games.csv")
data_clubs = pd.read_csv("data/clubs.csv")
data_competitions = pd.read_csv("data/competitions.csv")
data_games = pd.read_csv("data/games.csv")
data_player_valuations = pd.read_csv("data/player_valuations.csv")
data_players = pd.read_csv("data/players.csv")

# %%
data_appearances.head()
# Out:
#    appearance_id  game_id  player_id  player_club_id        date  \
# 0  2483937_52453  2483937      52453           28095  2014-08-08
# 1  2479929_67064  2479929      67064           28095  2014-08-03
# 2  2483937_67064  2483937      67064           28095  2014-08-08
# 3  2484582_67064  2484582      67064           28095  2014-08-13
# 4  2485965_67064  2485965      67064           28095  2014-08-16
#
#      player_pretty_name competition_id  yellow_cards  red_cards  goals  \
# 0         Haris Handzic            RU1             0          0      0
# 1  Felicio Brown Forbes            RU1             0          0      0
# 2  Felicio Brown Forbes            RU1             0          0      0
# 3  Felicio Brown Forbes            RU1             0          0      0
# 4  Felicio Brown Forbes            RU1             0          0      0
#
#    assists  minutes_played
# 0        0              90
# 1        0              90
# 2        0              90
# 3        0              55
# 4        0              90

# %%
data_club_games.head()
# Out:
#    club_id  game_id  own_goals  own_position   own_manager_name  opponent_id  \
# 0       58  2219794          3            -1  John van den Brom          498
# 1      131  2244388          3            -1      Tito Vilanova          418
# 2      383  2211607          4            -1      Dick Advocaat          610
# 3      720  2252846          1            -1      Vítor Pereira         2990
# 4       27  2229332          2            -1      Jupp Heynckes           16
#
#    opponent_goals  opponent_position opponent_manager_name hosting  is_win
# 0               2                 -1            Peter Maes    Home       1
# 1               2                 -1         José Mourinho    Home       1
# 2               2                 -1         Frank de Boer    Home       1
# 3               0                 -1         Pedro Emanuel    Home       1
# 4               1                 -1          Jürgen Klopp    Home       1

# %%
data_clubs.head()
# Out:
#    club_id                 name          pretty_name domestic_competition_id  \
# 0     1032           fc-reading           Fc Reading                     GB1
# 1     2323             orduspor             Orduspor                     TR1
# 2     1387       acn-siena-1904       Acn Siena 1904                     IT1
# 3     1071       wigan-athletic       Wigan Athletic                     GB1
# 4     2703  spartak-vladikavkaz  Spartak Vladikavkaz                     RU1
#
#    total_market_value  squad_size  average_age  foreigners_number  \
# 0               33.66          26         25.9                 12
# 1                 NaN           0          NaN                  0
# 2                4.32          30         26.2                  6
# 3               12.38          29         26.5                 14
# 4                 NaN           1         20.0                  0
#
#    foreigners_percentage  national_team_players                stadium_name  \
# 0                   46.2                      6  Select Car Leasing Stadium
# 1                    NaN                      0            19 Eylül Stadyum
# 2                   20.0                      2             Artemio Franchi
# 3                   48.3                      6                  DW Stadium
# 4                    NaN                      0  Republican Stadium Spartak
#
#    stadium_seats net_transfer_record        coach_name  \
# 0          24161             +£8.37m   Brian McDermott
# 1          11024                 +-0      Héctor Cúper
# 2          15373              £-6Th.       Serse Cosmi
# 3          25133            £-140Th.  Roberto Martínez
# 4          32464                 +-0  Vladimir Gazzaev
#
#                                                  url
# 0  https://www.transfermarkt.co.uk/fc-reading/sta...
# 1  https://www.transfermarkt.co.uk/orduspor/start...
# 2  https://www.transfermarkt.co.uk/acn-siena-1904...
# 3  https://www.transfermarkt.co.uk/wigan-athletic...
# 4  https://www.transfermarkt.co.uk/spartak-vladik...

# %%
data_competitions.head()
# Out:
#   competition_id      pretty_name             type            sub_type  \
# 0             L1       Bundesliga  domestic_league          first_tier
# 1            DFB        Dfb Pokal     domestic_cup        domestic_cup
# 2            DFL     Dfl Supercup            other  domestic_super_cup
# 3            NL1       Eredivisie  domestic_league          first_tier
# 4            NLP  Toto Knvb Beker     domestic_cup        domestic_cup
#
#    country_id country_name  country_latitude  country_longitude  \
# 0          40      Germany         51.163818          10.447831
# 1          40      Germany         51.163818          10.447831
# 2          40      Germany         51.163818          10.447831
# 3         122  Netherlands         52.243498           5.634323
# 4         122  Netherlands         52.243498           5.634323
#
#   domestic_league_code             name confederation  \
# 0                   L1       bundesliga        europa
# 1                   L1        dfb-pokal        europa
# 2                   L1     dfl-supercup        europa
# 3                  NL1       eredivisie        europa
# 4                  NL1  toto-knvb-beker        europa
#
#                                                  url
# 0  https://www.transfermarkt.co.uk/bundesliga/sta...
# 1  https://www.transfermarkt.co.uk/dfb-pokal/star...
# 2  https://www.transfermarkt.co.uk/dfl-supercup/s...
# 3  https://www.transfermarkt.co.uk/eredivisie/sta...
# 4  https://www.transfermarkt.co.uk/toto-knvb-beke...

# %%
data_games.head()
# Out:
#    game_id competition_id competition_type  season          round        date  \
# 0  2219794           BESC            other    2011          Final  2012-07-22
# 1  2244388            SUC            other    2012  final 1st leg  2012-08-22
# 2  2211607           NLSC            other    2012          Final  2012-08-05
# 3  2252846           POSU            other    2012          Final  2012-08-11
# 4  2229332            DFL            other    2012          Final  2012-08-12
#
#    home_club_id  away_club_id  home_club_goals  away_club_goals  ...  \
# 0            58           498                3                2  ...
# 1           131           418                3                2  ...
# 2           383           610                4                2  ...
# 3           720          2990                1                0  ...
# 4            27            16                2                1  ...
#
#   home_club_position  away_club_position  club_home_pretty_name  \
# 0                 -1                  -1         Rsc Anderlecht
# 1                 -1                  -1           Fc Barcelona
# 2                 -1                  -1          Psv Eindhoven
# 3                 -1                  -1               Fc Porto
# 4                 -1                  -1      Fc Bayern Munchen
#
#   club_away_pretty_name home_club_manager_name away_club_manager_name  \
# 0           Ksc Lokeren      John van den Brom             Peter Maes
# 1           Real Madrid          Tito Vilanova          José Mourinho
# 2        Ajax Amsterdam          Dick Advocaat          Frank de Boer
# 3     Academica Coimbra          Vítor Pereira          Pedro Emanuel
# 4     Borussia Dortmund          Jupp Heynckes           Jürgen Klopp
#
#                          stadium attendance               referee  \
# 0  Constant Vanden Stock Stadion      14485     Laurent Colemonts
# 1               Spotify Camp Nou      91728     Carlos Clos Gómez
# 2            Johan Cruijff ArenA      50000         Björn Kuipers
# 3              Estádio do Dragão      26000  Olegário Benquerença
# 4                  Allianz Arena      69000        Michael Weiner
#
#                                                  url
# 0  https://www.transfermarkt.co.uk/spielbericht/i...
# 1  https://www.transfermarkt.co.uk/spielbericht/i...
# 2  https://www.transfermarkt.co.uk/spielbericht/i...
# 3  https://www.transfermarkt.co.uk/spielbericht/i...
# 4  https://www.transfermarkt.co.uk/spielbericht/i...
#
# [5 rows x 21 columns]

# %%
data_player_valuations.head()
# Out:
#          date    datetime    dateweek  player_id  current_club_id  \
# 0  2013-07-22  2013-07-22  2013-07-22     254016              855
# 1  2014-01-14  2014-01-14  2014-01-13     254016              855
# 2  2008-08-25  2008-08-25  2008-08-25      51053               23
# 3  2011-05-30  2011-05-30  2011-05-30      51053               23
# 4  2011-08-26  2011-08-26  2011-08-22      51053               23
#
#    market_value player_club_domestic_competition_id
# 0         90000                                 FR1
# 1         90000                                 FR1
# 2         90000                                  L1
# 3         90000                                  L1
# 4        225000                                  L1

# %%
data_players.head()
# Out:
#    player_id        pretty_name  club_id        club_pretty_name  \
# 0     254016   Arthur Delalande      855             Ea Guingamp
# 1      51053      Daniel Davari       23  Eintracht Braunschweig
# 2      31451      Torsten Oehrl       23  Eintracht Braunschweig
# 3      44622  Vladimir Kisenkov     3691               Tom Tomsk
# 4      30802         Oscar Diaz     3302              Ud Almeria
#
#    current_club_id country_of_citizenship country_of_birth  city_of_birth  \
# 0              855                 France           France   Saint-Malo
# 1               23                   Iran          Germany       Gießen
# 2               23                Germany          Germany  Lichtenfels
# 3             3691                 Russia            UdSSR       Kaluga
# 4             3302                  Spain            Spain       Madrid
#
#   date_of_birth    position  ... height_in_cm market_value_in_gbp  \
# 0    1992-05-18    Midfield  ...          186                 NaN
# 1    1988-01-06  Goalkeeper  ...          192            135000.0
# 2    1986-01-07      Attack  ...          192                 NaN
# 3    1981-10-08    Defender  ...          182                 NaN
# 4    1984-04-24      Attack  ...          183                 NaN
#
#   highest_market_value_in_gbp                agent_name  \
# 0                     90000.0                       NaN
# 1                   1130000.0                     NG360
# 2                   1130000.0                       NaN
# 3                    720000.0                       NaN
# 4                   1080000.0  Pedro Bravo - Consulting
#
#    contract_expiration_date  domestic_competition_id               club_name  \
# 0                       NaN                      FR1             ea-guingamp
# 1                2022-06-30                       L1  eintracht-braunschweig
# 2                       NaN                       L1  eintracht-braunschweig
# 3                       NaN                      RU1               tom-tomsk
# 4                2022-06-30                      ES1              ud-almeria
#
#   image_url last_season                                                url
# 0       NaN        2013  https://www.transfermarkt.co.uk/arthur-delalan...
# 1       NaN        2013  https://www.transfermarkt.co.uk/daniel-davari/...
# 2       NaN        2013  https://www.transfermarkt.co.uk/torsten-oehrl/...
# 3       NaN        2013  https://www.transfermarkt.co.uk/vladimir-kisen...
# 4       NaN        2013  https://www.transfermarkt.co.uk/oscar-diaz/pro...
#
# [5 rows x 23 columns]

# %%
# players of interest
interest = ['(?i).*\sMessi$', '(?i).*\sronaldo$', '(?i).*\smbappe$', '(?i).*\sneymar$']

# %%
temp = data_appearances.groupby(["player_id"])["goals"].sum().sort_values(ascending = False)
